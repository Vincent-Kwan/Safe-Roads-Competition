# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from util import truncate

# %%
pd.set_option('display.max_columns', None)

# %%
ksi_df = pd.read_csv('Data/KSI.csv')

# %%
# empty column just made so that we can take count in pivot table

ksi_df['COUNT'] = 1

# %%
ksi_df[ksi_df['ACCNUM'] == 892658]
# Out:
#               X             Y   INDEX_  ACCNUM  YEAR                    DATE  \
# 0 -8.844611e+06  5.412414e+06  3387730  892658  2006  2006/03/11 05:00:00+00
# 1 -8.844611e+06  5.412414e+06  3387731  892658  2006  2006/03/11 05:00:00+00
#
#    TIME  HOUR     STREET1      STREET2  OFFSET      ROAD_CLASS  \
# 0   852     8  BLOOR ST W  DUNDAS ST W  <Null>  Major Arterial
# 1   852     8  BLOOR ST W  DUNDAS ST W  <Null>  Major Arterial
#
#                 DISTRICT WARDNUM DIVISION   LATITUDE  LONGITUDE      LOCCOORD  \
# 0  Toronto and East York       4       11  43.656345  -79.45249  Intersection
# 1  Toronto and East York       4       11  43.656345  -79.45249  Intersection
#
#             ACCLOC        TRAFFCTL VISIBILITY     LIGHT RDSFCOND ACCLASS  \
# 0  At Intersection  Traffic Signal      Clear  Daylight      Dry   Fatal
# 1  At Intersection  Traffic Signal      Clear  Daylight      Dry   Fatal
#
#                IMPACTYPE     INVTYPE    INVAGE INJURY FATAL_NO INITDIR  \
# ...

# %%
ksi_df.iloc[ksi_df['ACCNUM'].drop_duplicates().index].head()
# Out:
#               X             Y   INDEX_  ACCNUM  YEAR                    DATE  \
# 0 -8.844611e+06  5.412414e+06  3387730  892658  2006  2006/03/11 05:00:00+00
# 2 -8.816480e+06  5.434843e+06  3388101  892810  2006  2006/03/11 05:00:00+00
# 4 -8.822759e+06  5.424516e+06  3387793  892682  2006  2006/03/12 05:00:00+00
# 7 -8.841082e+06  5.411337e+06  3388371  892913  2006  2006/03/12 05:00:00+00
# 9 -8.855097e+06  5.418678e+06  3389258  893251  2006  2006/03/15 05:00:00+00
#
#    TIME  HOUR          STREET1           STREET2  OFFSET      ROAD_CLASS  \
# 0   852     8       BLOOR ST W       DUNDAS ST W  <Null>  Major Arterial
# 2   915     9  MORNINGSIDE AVE    SHEPPARD AVE E  <Null>  Major Arterial
# 4   240     2   EGLINTON AVE E  COMMONWEALTH AVE  <Null>  Major Arterial
# 7  1903    19    OSSINGTON AVE       DUNDAS ST W  <Null>  Major Arterial
# 9  1535    15    ISLINGTON AVE          DIXON RD  <Null>  Major Arterial
#
# ...

# %%
accnum_list = ksi_df['ACCNUM'].unique()

# %%
len(accnum_list)
# Out:
# 6002

# %%
ksi_df['LATITUDE'] = ksi_df['LATITUDE'].apply(truncate, args = (2,))
ksi_df['LONGITUDE'] = ksi_df['LONGITUDE'].apply(truncate, args = (2,))

# %%
ksi_collapse = ksi_df.loc[ksi_df['ACCNUM'].drop_duplicates().index].pivot_table(values = ['COUNT'], index = ['LATITUDE', 'LONGITUDE'], aggfunc = 'count')

# %%
ksi_collapse.reset_index(inplace = True)

# %%
ksi_collapse
# Out:
#      LATITUDE  LONGITUDE  COUNT
# 0       43.59     -79.54      4
# 1       43.59     -79.53     11
# 2       43.59     -79.52      5
# 3       43.59     -79.51      6
# 4       43.59     -79.50      1
# ..        ...        ...    ...
# 683     43.84     -79.19      2
# 684     43.85     -79.19      1
# 685     43.85     -79.18      1
# 686     43.85     -79.17      5
# 687     43.85     -79.16      1
#
# [688 rows x 3 columns]

# %%
# this latitude and longitude has 2 accidents

ksi_df[(ksi_df['LATITUDE'] == 43.853) & (ksi_df['LONGITUDE'] == -79.179)]
# Out:
#                  X             Y   INDEX_   ACCNUM  YEAR  \
# 2270 -8.814276e+06  5.442744e+06  4274318  1000440  2007
# 2278 -8.814276e+06  5.442744e+06  4274319  1000440  2007
# 2456 -8.814276e+06  5.442744e+06  4196587   981104  2007
# 2461 -8.814276e+06  5.442744e+06  4196588   981104  2007
# 2466 -8.814276e+06  5.442744e+06  4196589   981104  2007
# 2472 -8.814276e+06  5.442744e+06  4196590   981104  2007
#
#                         DATE  TIME  HOUR         STREET1     STREET2  ...  \
# 2270  2007/10/21 04:00:00+00  1449    14  STEELES Aven E  BEARE Road  ...
# 2278  2007/10/21 04:00:00+00  1449    14  STEELES Aven E  BEARE Road  ...
# 2456  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  ...
# 2461  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  ...
# 2466  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  ...
# 2472  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  ...
#
# ...

# %%
ksi_collapse.to_csv('KSI_Collapse_Count_round2.csv')
