# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
ksi_df = pd.read_csv('Data/KSI.csv')

# %%
# empty column just made so that we can take count in pivot table

ksi_df['COUNT'] = 1

# %%
accnum_list = ksi_df['ACCNUM'].unique()

# %%
len(accnum_list)
# Out:
# 6002

# %%
ksi_collapse = ksi_df.loc[ksi_df['ACCNUM'].drop_duplicates().index].pivot_table(values = ['COUNT'], index = ['LATITUDE', 'LONGITUDE'], aggfunc = 'count')

# %%
ksi_collapse.reset_index(inplace = True)

# %%
ksi_collapse
# Out:
#        LATITUDE  LONGITUDE  COUNT
# 0     43.590289 -79.526683      1
# 1     43.592047 -79.534717      1
# 2     43.592545 -79.541790      1
# 3     43.592673 -79.542079      1
# 4     43.593039 -79.541560      1
# ...         ...        ...    ...
# 5340  43.853145 -79.179990      2
# 5341  43.854145 -79.169690      1
# 5342  43.854245 -79.175490      1
# 5343  43.855197 -79.171344      1
# 5344  43.855445 -79.170284      1
#
# [5345 rows x 3 columns]

# %%
# this latitude and longitude has 2 accidents

ksi_df[(ksi_df['LATITUDE'] == 43.853145) & (ksi_df['LONGITUDE'] == -79.179990)]
# Out:
#                  X             Y   INDEX_   ACCNUM  YEAR  \
# 2270 -8.814276e+06  5.442744e+06  4274318  1000440  2007
# 2278 -8.814276e+06  5.442744e+06  4274319  1000440  2007
# 2456 -8.814276e+06  5.442744e+06  4196587   981104  2007
# 2461 -8.814276e+06  5.442744e+06  4196588   981104  2007
# 2466 -8.814276e+06  5.442744e+06  4196589   981104  2007
# 2472 -8.814276e+06  5.442744e+06  4196590   981104  2007
#
#                         DATE  TIME  HOUR         STREET1     STREET2  OFFSET  \
# 2270  2007/10/21 04:00:00+00  1449    14  STEELES Aven E  BEARE Road  <Null>
# 2278  2007/10/21 04:00:00+00  1449    14  STEELES Aven E  BEARE Road  <Null>
# 2456  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  <Null>
# 2461  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  <Null>
# 2466  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  <Null>
# 2472  2007/06/23 04:00:00+00  1000    10   STEELES AVE E    BEARE RD  <Null>
#
#           ROAD_CLASS     DISTRICT WARDNUM DIVISION   LATITUDE  LONGITUDE  \
# 2270  Minor Arterial  Scarborough      25       42  43.853145  -79.17999
# 2278  Minor Arterial  Scarborough      25       42  43.853145  -79.17999
# 2456  Minor Arterial  Scarborough      25       42  43.853145  -79.17999
# 2461  Minor Arterial  Scarborough      25       42  43.853145  -79.17999
# 2466  Minor Arterial  Scarborough      25       42  43.853145  -79.17999
# 2472  Minor Arterial  Scarborough      25       42  43.853145  -79.17999
#
#           LOCCOORD           ACCLOC   TRAFFCTL VISIBILITY     LIGHT RDSFCOND  \
# 2270  Intersection           <Null>  Stop Sign      Clear  Daylight      Dry
# 2278  Intersection           <Null>  Stop Sign      Clear  Daylight      Dry
# 2456  Intersection  At Intersection  Stop Sign      Clear  Daylight      Dry
# 2461  Intersection  At Intersection  Stop Sign      Clear  Daylight      Dry
# 2466  Intersection  At Intersection  Stop Sign      Clear  Daylight      Dry
# 2472  Intersection  At Intersection  Stop Sign      Clear  Daylight      Dry
#
#                ACCLASS IMPACTYPE            INVTYPE    INVAGE   INJURY  \
# 2270  Non-Fatal Injury     Angle  Motorcycle Driver  45 to 49    Major
# 2278  Non-Fatal Injury     Angle             Driver  55 to 59     None
# 2456  Non-Fatal Injury     Angle             Driver  45 to 49    Major
# 2461  Non-Fatal Injury     Angle          Passenger  45 to 49    Major
# 2466  Non-Fatal Injury     Angle      Vehicle Owner   unknown     None
# 2472  Non-Fatal Injury     Angle             Driver  40 to 44  Minimal
#
#      FATAL_NO INITDIR                    VEHTYPE    MANOEUVER  \
# 2270   <Null>    East                 Motorcycle  Going Ahead
# 2278   <Null>   North  Automobile, Station Wagon  Going Ahead
# 2456   <Null>    East                      Other  Going Ahead
# 2461   <Null>  <Null>                      Other       <Null>
# 2466   <Null>  <Null>                      Other       <Null>
# 2472   <Null>   South  Automobile, Station Wagon  Going Ahead
#
#                            DRIVACT     DRIVCOND PEDTYPE  PEDACT PEDCOND  \
# 2270              Driving Properly       Normal  <Null>  <Null>  <Null>
# 2278  Failed to Yield Right of Way  Inattentive  <Null>  <Null>  <Null>
# 2456              Driving Properly       Normal  <Null>  <Null>  <Null>
# 2461                        <Null>       <Null>  <Null>  <Null>  <Null>
# 2466                        <Null>       <Null>  <Null>  <Null>  <Null>
# 2472  Failed to Yield Right of Way  Inattentive  <Null>  <Null>  <Null>
#
#      CYCLISTYPE  CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE  \
# 2270     <Null>  <Null>  <Null>     <Null>  <Null>        Yes        Yes
# 2278     <Null>  <Null>  <Null>     <Null>  <Null>        Yes        Yes
# 2456     <Null>  <Null>  <Null>     <Null>  <Null>        Yes     <Null>
# 2461     <Null>  <Null>  <Null>     <Null>  <Null>        Yes     <Null>
# 2466     <Null>  <Null>  <Null>     <Null>  <Null>        Yes     <Null>
# 2472     <Null>  <Null>  <Null>     <Null>  <Null>        Yes     <Null>
#
#        TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT  \
# 2270  <Null>        <Null>    <Null>    <Null>   <Null>     Yes   <Null>
# 2278  <Null>        <Null>    <Null>    <Null>   <Null>     Yes   <Null>
# 2456  <Null>        <Null>    <Null>       Yes   <Null>     Yes   <Null>
# 2461  <Null>        <Null>    <Null>       Yes   <Null>     Yes   <Null>
# 2466  <Null>        <Null>    <Null>       Yes   <Null>     Yes   <Null>
# 2472  <Null>        <Null>    <Null>       Yes   <Null>     Yes   <Null>
#
#      ALCOHOL DISABILITY POLICE_DIVISION  HOOD_ID NEIGHBOURHOOD  ObjectId
# 2270  <Null>     <Null>             D42      131   Rouge (131)      2271
# 2278  <Null>     <Null>             D42      131   Rouge (131)      2279
# 2456  <Null>     <Null>             D42      131   Rouge (131)      2457
# 2461  <Null>     <Null>             D42      131   Rouge (131)      2462
# 2466  <Null>     <Null>             D42      131   Rouge (131)      2467
# 2472  <Null>     <Null>             D42      131   Rouge (131)      2473

# %%
ksi_collapse.to_csv('KSI_Collapse_Count.csv')
