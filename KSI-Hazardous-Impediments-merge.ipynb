# %%
import pandas as pd
import util
import numpy as np

# %%
hazardous_df = pd.read_csv('Data/Hazardous_Driving_Areas_Toronto.csv')
road = pd.read_csv('Data/Road_Impediments_Rounded3.csv')
ksi_count = pd.read_csv('Data/Created Datasets/KSI_Collapse_Count_truncate3.csv', index_col = 0)
ksi_feature = pd.read_csv('Data/Created Datasets/KSI_Feature_Collapse.csv', index_col = 0)

# %%
# only need to aggregate hazardous
# road is already in aggregated form

hazardous_df = hazardous_df[['Latitude' , 'Longitude' , 'IncidentsTotal', 'SeverityScore']]
hazardous_df['Longitude'] = hazardous_df['Longitude'].apply(util.truncate, args = (3, ))
hazardous_df['Latitude'] = hazardous_df['Latitude'].apply(util.truncate, args = (3,))
hazardous_df = hazardous_df.pivot_table(values = ['IncidentsTotal', 'SeverityScore'], index = ['Latitude', 'Longitude'], aggfunc = {'IncidentsTotal': sum, 'SeverityScore': np.mean}).reset_index()

# %%
# Merging
# need a right merge here
# because places that might have road impediments might not have harsh breaking incidents

# KEEP IN MIND THAT I HAD INNER MERGE BEFORE - FOR POSTERITY'S SAKE

merge = hazardous_df.merge(road, on = ['Latitude', 'Longitude'], how = 'right')

# %%
merge
# Out:
#        Latitude  Longitude  IncidentsTotal  SeverityScore  PercentOfVehicles  \
# 0        37.801    -95.952             NaN            NaN              0.008
# 1        43.645    -79.393             NaN            NaN              0.094
# 2        43.609    -79.555           687.0         0.0585              0.002
# 3        43.685    -79.283             NaN            NaN              0.092
# 4        43.669    -79.426             NaN            NaN              0.045
# ...         ...        ...             ...            ...                ...
# 49995    43.690    -79.359             NaN            NaN              0.000
# 49996    43.690    -79.400             NaN            NaN              0.087
# 49997    43.690    -79.358             NaN            NaN              0.023
# 49998    43.690    -79.369             NaN            NaN              0.003
# 49999    43.690    -79.565             NaN            NaN              0.057
#
#        AvgAcceleration  PercentCar  PercentMPV  PercentLDT  PercentMDT  \
# 0                0.268       0.000       0.030       0.653       0.065
# 1                0.732       0.023       0.261       0.298       0.094
# 2                0.562       0.022       0.125       0.279       0.067
# 3                0.467       0.004       0.236       0.407       0.107
# 4                0.520       0.011       0.306       0.229       0.107
# ...                ...         ...         ...         ...         ...
# 49995            0.000       0.030       0.121       0.291       0.016
# 49996            0.436       0.017       0.475       0.203       0.067
# 49997            0.343       0.000       0.527       0.344       0.076
# 49998            0.462       0.127       0.215       0.424       0.112
# 49999            0.265       0.000       0.227       0.205       0.080
#
#        PercentHDT  PercentOther
# 0           0.201         0.050
# 1           0.179         0.145
# 2           0.363         0.143
# 3           0.052         0.195
# 4           0.127         0.221
# ...           ...           ...
# 49995       0.161         0.382
# 49996       0.043         0.195
# 49997       0.008         0.046
# 49998       0.048         0.074
# 49999       0.330         0.159
#
# [50000 rows x 12 columns]

# %%
# Semi-Final merge with ksi_count

merge =  merge.merge(ksi_count, left_on = ['Latitude', 'Longitude'], right_on = ['LATITUDE', 'LONGITUDE'], how = 'inner')

# %%
merge
# Out:
#       Latitude  Longitude  IncidentsTotal  SeverityScore  PercentOfVehicles  \
# 0       43.676    -79.397             NaN            NaN              0.012
# 1       43.651    -79.445             NaN            NaN              0.035
# 2       43.808    -79.321             NaN            NaN              0.059
# 3       43.685    -79.481             NaN            NaN              0.005
# 4       43.682    -79.445             NaN            NaN              0.023
# ...        ...        ...             ...            ...                ...
# 3344    43.699    -79.519             NaN            NaN              0.061
# 3345    43.699    -79.587             7.0          0.009              0.047
# 3346    43.699    -79.318             NaN            NaN              0.074
# 3347    43.690    -79.292             NaN            NaN              0.006
# 3348    43.690    -79.376             NaN            NaN              0.080
#
#       AvgAcceleration  PercentCar  PercentMPV  PercentLDT  PercentMDT  \
# 0               0.320       0.059       0.220       0.333       0.081
# 1               0.680       0.025       0.172       0.345       0.094
# 2               0.124       0.000       0.647       0.353       0.000
# 3               0.274       0.022       0.118       0.353       0.073
# 4               0.403       0.028       0.193       0.363       0.069
# ...               ...         ...         ...         ...         ...
# 3344            0.603       0.031       0.212       0.512       0.060
# 3345            0.425       0.004       0.069       0.199       0.085
# 3346            0.590       0.047       0.245       0.401       0.074
# 3347            0.462       0.056       0.249       0.346       0.080
# 3348            0.355       0.017       0.364       0.323       0.137
#
#       PercentHDT  PercentOther  LATITUDE  LONGITUDE  COUNT
# 0          0.116         0.191    43.676    -79.397      1
# 1          0.197         0.167    43.651    -79.445      2
# 2          0.000         0.000    43.808    -79.321      1
# 3          0.237         0.197    43.685    -79.481      1
# 4          0.150         0.198    43.682    -79.445      1
# ...          ...           ...       ...        ...    ...
# 3344       0.081         0.103    43.699    -79.519      1
# 3345       0.488         0.155    43.699    -79.587      1
# 3346       0.123         0.109    43.699    -79.318      1
# 3347       0.152         0.118    43.690    -79.292      2
# 3348       0.089         0.071    43.690    -79.376      1
#
# [3349 rows x 15 columns]

# %%
# Final merge with ksi_feature

final_merge = merge.merge(ksi_feature, on = ['LATITUDE', 'LONGITUDE'], how = 'inner')

# %%
ksi_feature[(ksi_feature['LONGITUDE'] ==-79.321) & (ksi_feature['LATITUDE'] ==43.808)]
# Out:
#       LATITUDE  LONGITUDE    INVAGE WARDNUM RDSFCOND VISIBILITY     LIGHT  \
# 3759    43.808    -79.321  25 to 29      22      Dry      Clear  Daylight
#
#         TRAFFCTL                    VEHTYPE           DRIVACT DRIVCOND  \
# 3759  No Control  Automobile, Station Wagon  Driving Properly   Normal
#
#      SPEEDING AG_DRIV ALCOHOL DISABILITY REDLIGHT    MANOEUVER
# 3759   <Null>  <Null>  <Null>     <Null>   <Null>  Going Ahead

# %%
final_merge
# Out:
#       Latitude  Longitude  IncidentsTotal  SeverityScore  PercentOfVehicles  \
# 0       43.676    -79.397             NaN            NaN              0.012
# 1       43.651    -79.445             NaN            NaN              0.035
# 2       43.808    -79.321             NaN            NaN              0.059
# 3       43.685    -79.481             NaN            NaN              0.005
# 4       43.682    -79.445             NaN            NaN              0.023
# ...        ...        ...             ...            ...                ...
# 3318    43.699    -79.519             NaN            NaN              0.061
# 3319    43.699    -79.587             7.0          0.009              0.047
# 3320    43.699    -79.318             NaN            NaN              0.074
# 3321    43.690    -79.292             NaN            NaN              0.006
# 3322    43.690    -79.376             NaN            NaN              0.080
#
#       AvgAcceleration  PercentCar  PercentMPV  PercentLDT  PercentMDT  ...  \
# 0               0.320       0.059       0.220       0.333       0.081  ...
# 1               0.680       0.025       0.172       0.345       0.094  ...
# 2               0.124       0.000       0.647       0.353       0.000  ...
# 3               0.274       0.022       0.118       0.353       0.073  ...
# 4               0.403       0.028       0.193       0.363       0.069  ...
# ...               ...         ...         ...         ...         ...  ...
# 3318            0.603       0.031       0.212       0.512       0.060  ...
# 3319            0.425       0.004       0.069       0.199       0.085  ...
# 3320            0.590       0.047       0.245       0.401       0.074  ...
# 3321            0.462       0.056       0.249       0.346       0.080  ...
# 3322            0.355       0.017       0.364       0.323       0.137  ...
#
#             TRAFFCTL                    VEHTYPE                       DRIVACT  \
# 0         No Control  Automobile, Station Wagon              Driving Properly
# 1         No Control  Automobile, Station Wagon  Failed to Yield Right of Way
# 2         No Control  Automobile, Station Wagon              Driving Properly
# 3     Traffic Signal  Automobile, Station Wagon              Driving Properly
# 4         No Control  Automobile, Station Wagon                  Lost control
# ...              ...                        ...                           ...
# 3318  Traffic Signal  Automobile, Station Wagon  Failed to Yield Right of Way
# 3319  Traffic Signal  Automobile, Station Wagon              Driving Properly
# 3320      No Control  Automobile, Station Wagon              Driving Properly
# 3321       Stop Sign  Automobile, Station Wagon                        <Null>
# 3322      No Control  Automobile, Station Wagon                         Other
#
#                                 DRIVCOND  SPEEDING AG_DRIV ALCOHOL DISABILITY  \
# 0                            Inattentive    <Null>     Yes  <Null>     <Null>
# 1                                 Normal    <Null>  <Null>  <Null>     <Null>
# 2                                 Normal    <Null>  <Null>  <Null>     <Null>
# 3                                 Normal       Yes     Yes  <Null>     <Null>
# 4                                 Normal    <Null>     Yes  <Null>     <Null>
# ...                                  ...       ...     ...     ...        ...
# 3318                         Inattentive    <Null>     Yes  <Null>     <Null>
# 3319                              Normal    <Null>  <Null>  <Null>     <Null>
# 3320  Ability Impaired, Alcohol Over .08       Yes     Yes     Yes     <Null>
# 3321                              <Null>    <Null>  <Null>  <Null>     <Null>
# 3322                              Normal       Yes     Yes  <Null>     <Null>
#
#      REDLIGHT      MANOEUVER
# 0      <Null>    Going Ahead
# 1      <Null>    Going Ahead
# 2      <Null>    Going Ahead
# 3      <Null>    Going Ahead
# 4      <Null>    Going Ahead
# ...       ...            ...
# 3318   <Null>  Turning Right
# 3319   <Null>        Stopped
# 3320   <Null>    Going Ahead
# 3321   <Null>  Turning Right
# 3322   <Null>      Reversing
#
# [3323 rows x 30 columns]

# %%
final_merge.drop(['Latitude', 'Longitude'], axis = 1, inplace = True)

# %%
final_merge.to_csv('ALL_merge_truncate3.csv')
