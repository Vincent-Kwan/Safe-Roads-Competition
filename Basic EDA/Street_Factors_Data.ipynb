# %% [markdown]
# <a href="https://colab.research.google.com/github/Vincent-Kwan/Safe-Roads-Competition/blob/master/Street_Factors_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ksi = pd.read_csv('KSI.csv')

# %%
ksi[(ksi['STREET1']== 'BAY ST') | (ksi['STREET2']=='BAY ST') & (ksi['INITDIR']=='South') | (ksi['INITDIR']=='North')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# There are no left turns permitted onto Bay St.
# Traffic coming onto Bay St. via non-major roads only has stop signs not traffic lights

# %%
ksi[(ksi['STREET1']== 'BAY ST') | (ksi['STREET2']=='BAY ST') & (ksi['INITDIR']=='South') | (ksi['INITDIR']=='North')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# There are no bike lanes on Bay St.

# %%
ksi[(ksi['STREET1']== 'ADELAIDE ST E') | (ksi['STREET2']== 'ADELAIDE ST E')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')

# %%
ksi[(ksi['STREET1']== 'ADELAIDE ST E') | (ksi['STREET2']== 'ADELAIDE ST E')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# There are no bicycle lanes on Adelaide St.

# %%
ksi[(ksi['STREET1']== 'KING ST W') | (ksi['STREET2']== 'KING ST W')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')

# %%
ksi[(ksi['STREET1']== 'SPADINA AVE') | (ksi['STREET2']== 'SPADINA AVE')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')

# %%
ksi[(ksi['STREET1']== 'SPADINA AVE') | (ksi['STREET2']== 'SPADINA AVE')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
#No pedestrian crossing on Spadina & Lake Shore North Side. Pedestrians might be jaywalking across large/busy intersection
# No bike lane

# %%
ksi[(ksi['STREET1']== 'SPADINA AVE') | (ksi['STREET2']== 'SPADINA AVE')].groupby('VEHTYPE')['ACCNUM'].nunique().plot(kind='bar')
# Street car track going west cuts into car lane going north right before the lights.

# %%
ksi[(ksi['STREET1']== 'F G GARDINER XY E  E') | (ksi['STREET2']== 'F G GARDINER XY E  E')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# Cannot park on the expressway. Cars pulled off on the shoulder are getting hit.

# %%
ksi[(ksi['STREET1']== 'FRONT ST E') | (ksi['STREET2']== 'CHURCH ST')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# Split pedestrian crossing.

# %%
ksi[(ksi['STREET1']== 'FRONT ST E') | (ksi['STREET2']== 'CHURCH ST')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# Wide left turns on Front St E, Church St, and Wellington St intersection

# %%
ksi[(ksi['STREET1']== 'FRONT ST E') | (ksi['STREET2']== 'GEORGE ST')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# Again, split pedestrian crossing

# %%
ksi[(ksi['STREET1']== 'FRONT ST E') | (ksi['STREET2']== 'GEORGE ST')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# Lane narrows going East on Front St E. Cars can park on the curb, so merges into one lane.

# %%
ksi[(ksi['STREET1']== 'F G GARDINER XY E  E') | (ksi['STREET2']== 'F G GARDINER XY E  E')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# Why are pedestrians crossing the expressway? There is no pedestrian crossing.

# %%
ksi[(ksi['STREET1']== 'F G GARDINER XY E  E') | (ksi['STREET2']== 'SPADINA AVE')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# Coming off the expressway onto Spadina. Might still be speeding.

# %%
ksi[(ksi['STREET1']== 'QUEEN ST W') | (ksi['STREET2']== 'UNIVERSITY AVE')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# No left turn from University Ave onto Queen St. 
# No bicycle lanes on University Ave

# %%
ksi[(ksi['STREET1']== 'QUEEN ST W') | (ksi['STREET2']== 'UNIVERSITY AVE')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# Split pedestrian crossing. Same situation at Church St. and Front Side Ave. More collisions at split crossings?

# %%
ksi[(ksi['STREET1']== 'QUEENS QUAY E') | (ksi['STREET2']== 'YONGE ST')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# Wide right turn from Queens Quay E onto Yonge St.

# %%
ksi[(ksi['STREET1']== 'QUEENS QUAY E') | (ksi['STREET2']== 'YONGE ST')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# Cyclists knocking into pedestrians?

# %%
ksi[(ksi['STREET1']== 'QUEENS QUAY E') | (ksi['STREET2']== 'PARLIMENT ST')].groupby('MANOEUVER')['ACCNUM'].nunique().plot(kind='bar')
# There are no traffic controls for vehicles coming off Small St. and Merchant's Wharf where Queen's Quay meets Parliment St. No lights, no stop signs, no bicycle lanes.

# %%
ksi[(ksi['STREET1']== 'QUEENS QUAY E') | (ksi['STREET2']== 'PARLIMENT ST')].groupby('IMPACTYPE')['ACCNUM'].nunique().plot(kind='bar')
# There is no pedestrian crossing or bicycle lanes in this section of road.
