# %%
import pandas as pd
import numpy as np
import os
import util

# %%
pd.set_option('max_columns', None)

# %%
parent = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# %%
ped_collapse = pd.read_csv(parent + '\Data\Created datasets\KSI_Pedestrian_Count_truncate3.csv', index_col = 0)
ksi_df = pd.read_csv(parent + '\Data\KSI.csv')

# %%
# including PEDTYPE too - but it is probably VERY highly correlated with PEDACT
# investigate this if you want to reduce dimensionality

cols = ['PEDTYPE', 'PEDACT', 'PEDCOND', 'TRAFFCTL', 'LIGHT', 'VISIBILITY', 'RDSFCOND']

# %%
ksi_df['LATITUDE'] = ksi_df['LATITUDE'].apply(util.truncate, args = (3, ))
ksi_df['LONGITUDE'] = ksi_df['LONGITUDE'].apply(util.truncate, args = (3, ))

# %%
# conditions important

ksi_df = ksi_df[(ksi_df['IMPACTYPE'] == 'Pedestrian Collisions') & (ksi_df['INVTYPE'] == 'Pedestrian')]

# %%
ksi_df['COMBINED'] = ksi_df[cols].apply(tuple, axis = 1)

# %%
time_df = ksi_df.groupby(['LATITUDE', 'LONGITUDE'])['TIME'].apply(lambda x: x.mean()).reset_index()

# %%
# level_2 indicates # of modes returned
# important because multiple drivers may have been at fault

# mode taken ACROSS columns

feature_collapse = ksi_df.groupby(['LATITUDE', 'LONGITUDE'])['COMBINED'].apply(lambda x: x.mode()).reset_index()

feature_collapse
# Out:
#       LATITUDE  LONGITUDE  level_2  \
# 0       43.594    -79.533        0
# 1       43.594    -79.533        1
# 2       43.595    -79.528        0
# 3       43.597    -79.522        0
# 4       43.598    -79.516        0
# ...        ...        ...      ...
# 2543    43.836    -79.251        0
# 2544    43.836    -79.251        1
# 2545    43.836    -79.231        0
# 2546    43.837    -79.249        0
# 2547    43.837    -79.245        0
#
#                                                COMBINED
# 0     (Vehicle is going straight thru inter.while pe...
# 1     (Vehicle turns left while ped crosses with ROW...
# 2     (<Null>, Other, Other, No Control, Dark, artif...
# 3     (Vehicle is reversing and hits pedestrian, Oth...
# 4     (Vehicle is going straight thru inter.while pe...
# ...                                                 ...
# 2543  (Vehicle is going straight thru inter.while pe...
# 2544  (Vehicle turns left while ped crosses with ROW...
# 2545  (Pedestrian involved in a collision with trans...
# 2546  (Pedestrian hit at mid-block, Running onto Roa...
# 2547  (Pedestrian hit at mid-block, Crossing, no Tra...
#
# [2548 rows x 4 columns]

# %%
feature_collapse = feature_collapse.join(feature_collapse['COMBINED'].apply(pd.Series, index = cols))
feature_collapse = feature_collapse.merge(time_df, on = ['LATITUDE', 'LONGITUDE'], how = 'inner')
feature_collapse.drop(['level_2', 'COMBINED'], axis = 1, inplace = True)

# %%
feature_collapse
# Out:
#       LATITUDE  LONGITUDE                                            PEDTYPE  \
# 0       43.594    -79.533  Vehicle is going straight thru inter.while ped...
# 1       43.594    -79.533  Vehicle turns left while ped crosses with ROW ...
# 2       43.595    -79.528                                             <Null>
# 3       43.597    -79.522           Vehicle is reversing and hits pedestrian
# 4       43.598    -79.516  Vehicle is going straight thru inter.while ped...
# ...        ...        ...                                                ...
# 2543    43.836    -79.251  Vehicle is going straight thru inter.while ped...
# 2544    43.836    -79.251  Vehicle turns left while ped crosses with ROW ...
# 2545    43.836    -79.231  Pedestrian involved in a collision with transi...
# 2546    43.837    -79.249                        Pedestrian hit at mid-block
# 2547    43.837    -79.245                        Pedestrian hit at mid-block
#
#                                      PEDACT      PEDCOND        TRAFFCTL  \
# 0     Crossing marked crosswalk without ROW  Inattentive  Traffic Signal
# 1                Crossing with right of way       Normal  Traffic Signal
# 2                                     Other        Other      No Control
# 3                                     Other       Normal      No Control
# 4                      Running onto Roadway       Normal  Traffic Signal
# ...                                     ...          ...             ...
# 2543             Crossing with right of way       Normal  Traffic Signal
# 2544             Crossing with right of way       Normal  Traffic Signal
# 2545                   Running onto Roadway  Inattentive      No Control
# 2546                   Running onto Roadway  Inattentive      No Control
# 2547           Crossing, no Traffic Control      Unknown      No Control
#
#                  LIGHT VISIBILITY RDSFCOND         TIME
# 0             Daylight      Clear      Dry  1367.000000
# 1                 Dusk      Clear      Dry  1367.000000
# 2     Dark, artificial      Clear      Dry  1949.000000
# 3             Daylight      Clear      Dry   600.000000
# 4                 Dark       Rain      Wet  1956.333333
# ...                ...        ...      ...          ...
# 2543  Dusk, artificial       Rain      Wet  1305.500000
# 2544  Dark, artificial       Rain      Wet  1305.500000
# 2545          Daylight      Clear      Dry   725.000000
# 2546              Dark      Clear      Dry  2054.000000
# 2547              Dark      Other    Other  2151.000000
#
# [2548 rows x 10 columns]

# %%
ksi_df[(ksi_df['LONGITUDE'] == -79.533) & (ksi_df['LATITUDE'] == 43.594)]
# Out:
#                  X             Y   INDEX_   ACCNUM  YEAR  \
# 2288 -8.853683e+06  5.402879e+06  4275178  1008571  2007
# 3095 -8.853683e+06  5.402879e+06  5370894  1043273  2008
#
#                         DATE  TIME  HOUR            STREET1          STREET2  \
# 2288  2007/11/15 05:00:00+00   724     7  LAKE SHORE BLVD W  LONG BRANCH AVE
# 3095  2008/06/11 04:00:00+00  2010    20  LAKE SHORE BLVD W  LONG BRANCH AVE
#
#       OFFSET      ROAD_CLASS        DISTRICT WARDNUM DIVISION  LATITUDE  \
# 2288  <Null>  Major Arterial  Etobicoke York       3       22    43.594
# 3095  <Null>  Major Arterial  Etobicoke York       3       22    43.594
#
#       LONGITUDE      LOCCOORD           ACCLOC        TRAFFCTL VISIBILITY  \
# 2288    -79.533  Intersection  At Intersection  Traffic Signal      Clear
# 3095    -79.533  Intersection  At Intersection  Traffic Signal      Clear
#
#          LIGHT RDSFCOND           ACCLASS              IMPACTYPE     INVTYPE  \
# 2288  Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions  Pedestrian
# 3095      Dusk      Dry             Fatal  Pedestrian Collisions  Pedestrian
#
#         INVAGE INJURY FATAL_NO INITDIR VEHTYPE MANOEUVER DRIVACT DRIVCOND  \
# 2288  20 to 24  Major   <Null>   North   Other    <Null>  <Null>   <Null>
# 3095  60 to 64  Fatal       26   South   Other    <Null>  <Null>   <Null>
#
#                                                 PEDTYPE  \
# 2288  Vehicle is going straight thru inter.while ped...
# 3095  Vehicle turns left while ped crosses with ROW ...
#
#                                      PEDACT      PEDCOND CYCLISTYPE  CYCACT  \
# 2288  Crossing marked crosswalk without ROW  Inattentive     <Null>  <Null>
# 3095             Crossing with right of way       Normal     <Null>  <Null>
#
#      CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE   TRUCK TRSN_CITY_VEH  \
# 2288  <Null>        Yes  <Null>        Yes     <Null>  <Null>        <Null>
# 3095  <Null>        Yes  <Null>        Yes     <Null>  <Null>        <Null>
#
#      EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY  \
# 2288    <Null>    <Null>   <Null>  <Null>   <Null>  <Null>     <Null>
# 3095    <Null>    <Null>   <Null>     Yes   <Null>  <Null>     <Null>
#
#      POLICE_DIVISION  HOOD_ID     NEIGHBOURHOOD  ObjectId  \
# 2288             D22       19  Long Branch (19)      2289
# 3095             D22       19  Long Branch (19)      3096
#
#                                                COMBINED
# 2288  (Crossing marked crosswalk without ROW, Inatte...
# 3095  (Crossing with right of way, Normal, 2010, Tra...

# %%
# PEDTYPE <Null> and PEDACT, PEDCOND is Other
# weird

ksi_df[(ksi_df['LONGITUDE'] == -79.528) & (ksi_df['LATITUDE'] == 43.595)]
# Out:
#                   X             Y    INDEX_  ACCNUM  YEAR  \
# 16000 -8.853047e+06  5.403083e+06  81505308  342262  2020
#
#                          DATE  TIME  HOUR          STREET1          STREET2  \
# 16000  2020/02/17 05:00:00+00  1949    19  LAKE SHORE BV W  THIRTY NINTH ST
#
#               OFFSET      ROAD_CLASS        DISTRICT WARDNUM DIVISION  \
# 16000  15 m South of  Major Arterial  Etobicoke York       3       22
#
#        LATITUDE  LONGITUDE   LOCCOORD            ACCLOC    TRAFFCTL  \
# 16000    43.595    -79.528  Mid-Block  Non Intersection  No Control
#
#       VISIBILITY             LIGHT RDSFCOND           ACCLASS  \
# 16000      Clear  Dark, artificial      Dry  Non-Fatal Injury
#
#                    IMPACTYPE     INVTYPE    INVAGE INJURY FATAL_NO INITDIR  \
# 16000  Pedestrian Collisions  Pedestrian  30 to 34  Major   <Null>  <Null>
#
#       VEHTYPE MANOEUVER DRIVACT DRIVCOND PEDTYPE PEDACT PEDCOND CYCLISTYPE  \
# 16000  <Null>    <Null>  <Null>   <Null>  <Null>  Other   Other     <Null>
#
#        CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE   TRUCK  \
# 16000  <Null>  <Null>        Yes  <Null>        Yes     <Null>  <Null>
#
#       TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL  \
# 16000        <Null>    <Null>       Yes   <Null>     Yes   <Null>  <Null>
#
#       DISABILITY POLICE_DIVISION  HOOD_ID     NEIGHBOURHOOD  ObjectId  \
# 16000     <Null>             D22       19  Long Branch (19)     16001
#
#                                                 COMBINED
# 16000  (<Null>, Other, Other, 1949, No Control, Dark,...

# %%
feature_collapse.merge(ped_collapse, on = ['LATITUDE', 'LONGITUDE'], how = 'inner')
# Out:
#       LATITUDE  LONGITUDE                                            PEDTYPE  \
# 0       43.594    -79.533  Vehicle is going straight thru inter.while ped...
# 1       43.594    -79.533  Vehicle turns left while ped crosses with ROW ...
# 2       43.595    -79.528                                             <Null>
# 3       43.597    -79.522           Vehicle is reversing and hits pedestrian
# 4       43.598    -79.516  Vehicle is going straight thru inter.while ped...
# ...        ...        ...                                                ...
# 2543    43.836    -79.251  Vehicle is going straight thru inter.while ped...
# 2544    43.836    -79.251  Vehicle turns left while ped crosses with ROW ...
# 2545    43.836    -79.231  Pedestrian involved in a collision with transi...
# 2546    43.837    -79.249                        Pedestrian hit at mid-block
# 2547    43.837    -79.245                        Pedestrian hit at mid-block
#
#                                      PEDACT      PEDCOND        TRAFFCTL  \
# 0     Crossing marked crosswalk without ROW  Inattentive  Traffic Signal
# 1                Crossing with right of way       Normal  Traffic Signal
# 2                                     Other        Other      No Control
# 3                                     Other       Normal      No Control
# 4                      Running onto Roadway       Normal  Traffic Signal
# ...                                     ...          ...             ...
# 2543             Crossing with right of way       Normal  Traffic Signal
# 2544             Crossing with right of way       Normal  Traffic Signal
# 2545                   Running onto Roadway  Inattentive      No Control
# 2546                   Running onto Roadway  Inattentive      No Control
# 2547           Crossing, no Traffic Control      Unknown      No Control
#
#                  LIGHT VISIBILITY RDSFCOND         TIME  COUNT
# 0             Daylight      Clear      Dry  1367.000000      2
# 1                 Dusk      Clear      Dry  1367.000000      2
# 2     Dark, artificial      Clear      Dry  1949.000000      1
# 3             Daylight      Clear      Dry   600.000000      1
# 4                 Dark       Rain      Wet  1956.333333      2
# ...                ...        ...      ...          ...    ...
# 2543  Dusk, artificial       Rain      Wet  1305.500000      2
# 2544  Dark, artificial       Rain      Wet  1305.500000      2
# 2545          Daylight      Clear      Dry   725.000000      1
# 2546              Dark      Clear      Dry  2054.000000      1
# 2547              Dark      Other    Other  2151.000000      1
#
# [2548 rows x 11 columns]

# %%
feature_collapse.to_csv('Pedestrian_Feature_Count.csv')
