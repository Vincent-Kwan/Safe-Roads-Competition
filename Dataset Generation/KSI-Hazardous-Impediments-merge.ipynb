# %%
import pandas as pd
import util
import numpy as np
import os

# %%
parent = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# %%
hazardous_df = pd.read_csv(parent + '\Data\Hazardous_Driving_Areas_Toronto.csv')
road = pd.read_csv(parent + '\Data\Road_Impediments_Rounded3.csv')
ksi_count = pd.read_csv(parent + '\Data\Created Datasets/KSI_Collapse_Count_truncate3.csv', index_col = 0)
ksi_feature = pd.read_csv(parent + '\Data\Created Datasets/KSI_Feature_Collapse.csv', index_col = 0)

# %%
# only need to aggregate hazardous
# road is already in aggregated form

hazardous_df = hazardous_df[['Latitude' , 'Longitude' , 'IncidentsTotal', 'SeverityScore']]
hazardous_df['Longitude'] = hazardous_df['Longitude'].apply(util.truncate, args = (3, ))
hazardous_df['Latitude'] = hazardous_df['Latitude'].apply(util.truncate, args = (3,))
hazardous_df = hazardous_df.pivot_table(values = ['IncidentsTotal', 'SeverityScore'], index = ['Latitude', 'Longitude'], aggfunc = {'IncidentsTotal': np.mean, 'SeverityScore': np.mean}).reset_index()

# %%
road = road[['Latitude', 'Longitude', 'PercentOfVehicles', 'AvgAcceleration']]

# %%
# Merging
# need a right merge here
# because places that might have road impediments might not have harsh breaking incidents

# KEEP IN MIND THAT I HAD INNER MERGE BEFORE - FOR POSTERITY'S SAKE

merge = hazardous_df.merge(road, on = ['Latitude', 'Longitude'], how = 'inner')

# %%
merge
# Out:
#       Latitude  Longitude  IncidentsTotal  SeverityScore  PercentOfVehicles  \
# 0       40.474    -80.606            44.0          0.190              0.038
# 1       43.590    -79.545             3.0          0.012              0.068
# 2       43.591    -79.544            35.0          0.148              0.100
# 3       43.592    -79.543             6.0          0.026              0.073
# 4       43.593    -79.538             8.0          0.022              0.069
# ...        ...        ...             ...            ...                ...
# 2332    43.833    -79.251             4.0          0.004              0.015
# 2333    43.834    -79.247             3.0          0.009              0.028
# 2334    43.835    -79.251             8.0          0.037              0.049
# 2335    43.836    -79.251            15.0          0.019              0.037
# 2336    43.851    -79.188             3.0          0.032              0.011
#
#       AvgAcceleration
# 0               0.696
# 1               0.445
# 2               0.549
# 3               0.604
# 4               0.421
# ...               ...
# 2332            0.366
# 2333            0.480
# 2334            0.504
# 2335            0.324
# 2336            0.903
#
# [2337 rows x 6 columns]

# %%
# Semi-Final merge with ksi_count
# Again, right merge is being used here
# This is because not every place where a KSI incident occurred
# will be classified as a Hazardous Area or as having a Road Impediment by Geotab

merge =  merge.merge(ksi_count, left_on = ['Latitude', 'Longitude'], right_on = ['LATITUDE', 'LONGITUDE'], how = 'inner')

# %%
merge
# Out:
#      Latitude  Longitude  IncidentsTotal  SeverityScore  PercentOfVehicles  \
# 0      43.593    -79.538             8.0          0.022              0.069
# 1      43.610    -79.561             3.0          0.007              0.033
# 2      43.612    -79.562             8.0          0.009              0.059
# 3      43.613    -79.560             3.0          0.002              0.047
# 4      43.614    -79.546            31.0          0.013              0.002
# ..        ...        ...             ...            ...                ...
# 494    43.824    -79.246             5.0          0.005              0.046
# 495    43.825    -79.300            68.0          0.090              0.068
# 496    43.831    -79.275            22.0          0.027              0.087
# 497    43.833    -79.251             4.0          0.004              0.015
# 498    43.836    -79.251            15.0          0.019              0.037
#
#      AvgAcceleration  LATITUDE  LONGITUDE  COUNT
# 0              0.421    43.593    -79.538      3
# 1              0.419    43.610    -79.561      2
# 2              0.462    43.612    -79.562      1
# 3              0.309    43.613    -79.560      1
# 4              0.592    43.614    -79.546      1
# ..               ...       ...        ...    ...
# 494            0.370    43.824    -79.246      1
# 495            0.593    43.825    -79.300      3
# 496            0.546    43.831    -79.275      3
# 497            0.366    43.833    -79.251      1
# 498            0.324    43.836    -79.251      8
#
# [499 rows x 9 columns]

# %%
# Final merge with ksi_feature

final_merge = merge.merge(ksi_feature, on = ['LATITUDE', 'LONGITUDE'], how = 'inner')

# %%
final_merge
# Out:
#      Latitude  Longitude  IncidentsTotal  SeverityScore  PercentOfVehicles  \
# 0      43.593    -79.538             8.0          0.022              0.069
# 1      43.593    -79.538             8.0          0.022              0.069
# 2      43.593    -79.538             8.0          0.022              0.069
# 3      43.610    -79.561             3.0          0.007              0.033
# 4      43.613    -79.560             3.0          0.002              0.047
# ..        ...        ...             ...            ...                ...
# 701    43.836    -79.251            15.0          0.019              0.037
# 702    43.836    -79.251            15.0          0.019              0.037
# 703    43.836    -79.251            15.0          0.019              0.037
# 704    43.836    -79.251            15.0          0.019              0.037
# 705    43.836    -79.251            15.0          0.019              0.037
#
#      AvgAcceleration  LATITUDE  LONGITUDE  COUNT    INVAGE RDSFCOND  \
# 0              0.421    43.593    -79.538      3  25 to 29      Dry
# 1              0.421    43.593    -79.538      3  55 to 59      Dry
# 2              0.421    43.593    -79.538      3  70 to 74      Dry
# 3              0.419    43.610    -79.561      2   unknown      Wet
# 4              0.309    43.613    -79.560      1  55 to 59      Dry
# ..               ...       ...        ...    ...       ...      ...
# 701            0.324    43.836    -79.251      8  40 to 44      Dry
# 702            0.324    43.836    -79.251      8  40 to 44      Wet
# 703            0.324    43.836    -79.251      8  45 to 49      Dry
# 704            0.324    43.836    -79.251      8   unknown      Wet
# 705            0.324    43.836    -79.251      8   unknown      Wet
#
#     VISIBILITY                 LIGHT        TRAFFCTL  \
# 0        Clear              Daylight  Traffic Signal
# 1        Clear      Dark, artificial  Traffic Signal
# 2        Clear              Daylight  Traffic Signal
# 3         Rain                  Dark  Traffic Signal
# 4        Clear                  Dark  Traffic Signal
# ..         ...                   ...             ...
# 701      Clear              Daylight  Traffic Signal
# 702      Clear  Daylight, artificial      No Control
# 703      Clear              Daylight  Traffic Signal
# 704       Rain      Dark, artificial  Traffic Signal
# 705       Rain      Dusk, artificial  Traffic Signal
#
#                           DRIVACT     DRIVCOND                      VEHTYPE  \
# 0                   Improper Turn       Normal    Automobile, Station Wagon
# 1                   Improper Turn  Inattentive    Automobile, Station Wagon
# 2    Failed to Yield Right of Way  Inattentive    Automobile, Station Wagon
# 3                          <Null>       <Null>    Automobile, Station Wagon
# 4    Failed to Yield Right of Way  Inattentive    Automobile, Station Wagon
# ..                            ...          ...                          ...
# 701  Failed to Yield Right of Way       Normal    Automobile, Station Wagon
# 702                  Lost control  Inattentive    Automobile, Station Wagon
# 703     Disobeyed Traffic Control      Unknown    Automobile, Station Wagon
# 704  Failed to Yield Right of Way      Unknown  Municipal Transit Bus (TTC)
# 705  Failed to Yield Right of Way      Unknown    Automobile, Station Wagon
#
#      Cluster         TIME
# 0        1.0  1647.333333
# 1        7.0  1647.333333
# 2        7.0  1647.333333
# 3        1.0  2022.000000
# 4        7.0  1835.000000
# ..       ...          ...
# 701      5.0  1187.375000
# 702      3.0  1187.375000
# 703      6.0  1187.375000
# 704      5.0  1187.375000
# 705      5.0  1187.375000
#
# [706 rows x 19 columns]

# %%
final_merge.drop(['Latitude', 'Longitude'], axis = 1, inplace = True)

# %%
final_merge.to_csv('ALL_merge_truncate3.csv')
