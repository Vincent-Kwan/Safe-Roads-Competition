# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import util
import os

# %%
parent = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# %%
ksi_feature = pd.read_csv(parent + '\Data\Created Datasets\KSI_Feature_Collapse.csv', index_col = 0)
impediments_count = pd.read_csv(parent + '\Data\Created Datasets\KSI_Road_truncate3.csv', index_col = 0)

# %%
merged = ksi_feature.merge(impediments_count, on = ['LATITUDE', 'LONGITUDE'], how = 'inner')

# %%
merged
# Out:
#       LATITUDE  LONGITUDE    INVAGE RDSFCOND              VISIBILITY  \
# 0       43.592    -79.542  20 to 24      Wet  Fog, Mist, Smoke, Dust
# 1       43.592    -79.541  15 to 19      Dry                   Clear
# 2       43.592    -79.534  35 to 39      Dry                   Clear
# 3       43.593    -79.541  40 to 44      Wet                   Clear
# 4       43.593    -79.538  25 to 29      Dry                   Clear
# ...        ...        ...       ...      ...                     ...
# 3946    43.848    -79.199  25 to 29      Dry                   Clear
# 3947    43.850    -79.191  55 to 59      Wet                   Clear
# 3948    43.853    -79.179  40 to 44      Dry                   Clear
# 3949    43.853    -79.179  55 to 59      Dry                   Clear
# 3950    43.854    -79.175  20 to 24      Dry                   Clear
#
#                  LIGHT        TRAFFCTL                       DRIVACT  \
# ...

# %%
merged.to_csv('Impediments_Feature_Count.csv')
