# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ksi_collapse = pd.read_csv('Data/KSI_Collapse_Count.csv', index_col = 0)
road_df = pd.read_csv('Data/Road_Impediments_Toronto.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
road_df.head()
# Out:
#     Geohash                                      GeohashBounds  Latitude_SW  \
# 0  dpz2yfwh  POLYGON((-79.4998168945312 43.7400054931641, -...       43.740
# 1  dpz8u7gy  POLYGON((-79.2612075805664 43.7472152709961, -...       43.747
# 2  dpz9m1ny  POLYGON((-79.2241287231445 43.8199996948242, -...       43.820
# 3  dpz8dkqx  POLYGON((-79.3453216552734 43.7061882019043, -...       43.706
# 4  dpz91gd3  POLYGON((-79.3731307983398 43.7889289855957, -...       43.789
#
#    Longitude_SW  Latitude_NE  Longitude_NE                   Location  \
# 0       -79.500       43.740       -79.499  POINT(-79.49973 43.74017)
# 1       -79.261       43.747       -79.261  POINT(-79.26096 43.74731)
# 2       -79.224       43.820       -79.224  POINT(-79.22411 43.82008)
# 3       -79.345       43.706       -79.345  POINT(-79.34521 43.70632)
# 4       -79.373       43.789       -79.373  POINT(-79.37311 43.78904)
#
#    Latitude  Longitude     City  County    State Country ISO_3166_2  \
# ...

# %%
# only subsetting till AvgAcceleration

road_df = road_df.iloc[:, :15]

# %%
ksi_collapse = round(ksi_collapse, 3)

# %%
road_merge = road_df.merge(ksi_collapse, left_on = ['Latitude', 'Longitude'], right_on = ['LATITUDE', 'LONGITUDE'], how = 'inner')

# %%
road_merge
# Out:
#        Geohash                                      GeohashBounds  \
# 0     dpz91gd3  POLYGON((-79.3731307983398 43.7889289855957, -...
# 1     dpz91g6r  POLYGON((-79.3731307983398 43.7885856628418, -...
# 2     dpz91gd1  POLYGON((-79.3734741210938 43.7889289855957, -...
# 3     dpz91gd2  POLYGON((-79.3731307983398 43.7887573242188, -...
# 4     dpz91gde  POLYGON((-79.3727874755859 43.7892723083496, -...
# ...        ...                                                ...
# 7424  dpz836gr  POLYGON((-79.3937301635742 43.6540031433105, -...
# 7425  dpz8se3e  POLYGON((-79.2533111572266 43.700008392334, -7...
# 7426  dpz9hhgd  POLYGON((-79.2725372314453 43.7959671020508, -...
# 7427  dpz2u95f  POLYGON((-79.6017837524414 43.7314224243164, -...
# 7428  dpz83je9  POLYGON((-79.4043731689453 43.6680793762207, -...
#
#       Latitude_SW  Longitude_SW  Latitude_NE  Longitude_NE  \
# 0          43.789       -79.373       43.789       -79.373
# ...

# %%
road_merge.sort_values(by = 'COUNT', ascending = False)
# Out:
#        Geohash                                      GeohashBounds  \
# 6320  dpz97177  POLYGON((-79.3168258666992 43.820858001709, -7...
# 3110  dpz90v0r  POLYGON((-79.4198226928711 43.7981986999512, -...
# 6017  dpz2mw81  POLYGON((-79.56298828125 43.6735725402832, -79...
# 1897  dpz86ehd  POLYGON((-79.3370819091797 43.6545181274414, -...
# 879   dpz8252c  POLYGON((-79.4520950317383 43.6557197570801, -...
# ...        ...                                                ...
# 2615  dpz86prc  POLYGON((-79.3545913696289 43.6776924133301, -...
# 2614  dpz86prm  POLYGON((-79.3552780151367 43.6783790588379, -...
# 2612  dpz2wv32  POLYGON((-79.5063400268555 43.7104797363281, -...
# 2610  dpz2wv34  POLYGON((-79.5066833496094 43.710823059082, -7...
# 7428  dpz83je9  POLYGON((-79.4043731689453 43.6680793762207, -...
#
#       Latitude_SW  Longitude_SW  Latitude_NE  Longitude_NE  \
# 6320       43.821       -79.317       43.821       -79.316
# ...
